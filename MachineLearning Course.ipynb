# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayhan1/Data_Engineering/blob/main/MachineLearning%20Course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from random import randint
import matplotlib.pyplot as plt

test_data = pd.DataFrame({
    'x': [2, 4, 6, 8, 10, 12, 14],
    'y': [2, 3, 5, 8, 12, 17, 23]})

def algorithm(x, y, iteration, resolution):
    mse_list, m_list, b_list = [], [], []
    for i in range(iteration):
        val1 = np.random.random() * 10000 - 5000
        val2 = np.random.random() * 10000 - 5000
        for i in range(iteration):
            if val1 > 0:
                val1 = val1 - resolution
            elif val1 < 0:
                val1 = val1 + resolution
            else:
                pass
            mse, m = deploy_values(val1, val2, x, y)
            mse_list.append(mse)
            m_list.append(m)
            b_list.append(val2)
    results = pd.DataFrame({'mse': mse_list, 'm': m_list, 'b': b_list})
    global_minimum = results['mse'].min()
    optimal_values = results.loc[results['mse'] == global_minimum]
    slope = optimal_values['m'].iloc[0]
    intercept = optimal_values['b'].iloc[0]
    print(f"Slope: {slope}, Intercept: {intercept}")
    return global_minimum, slope, intercept, mse_list, b_list, m_list

def deploy_values(m, b, x, y):
    y_pred = (m * x) + b
    mse = ((y - y_pred) ** 2).mean()
    return mse, m

def predict(slope, intercept, x):
    return slope * x + intercept

model_1 = algorithm(test_data['x'], test_data['y'], iteration=1000, resolution=0.001)
print(model_1[1], model_1[2])
MSE = model_1[3]
MEAN = model_1[5]
plt.scatter(MEAN, MSE, color='red', label='MSE', s=0.1, alpha=0.2)
plt.xlabel('Mean')
plt.ylabel('MSE')
plt.legend()
plt.show()
# Out:
# Slope: -113.44017297077264, Intercept: 1303.0442770235832
# -113.44017297077264 1303.0442770235832

# %%
import pandas as pd
import numpy as np
from random import randint
import matplotlib.pyplot as plt

test_data = pd.DataFrame({
    'x': [1, 2, 3, 4, 5, 6, 7],
    'y': [2, 4, 6, 8, 10, 12, 14]})

def algorithm(x, y, iteration, resolution):
    mse_list, m_list, b_list = [], [], []
    for i in range(iteration):
        val1 = randint(-10000, 10000) / 1000
        val2 = randint(-10000, 10000) / 1000
        for i in range(iteration):
            if val1 > 0:
                val1 = val1 - resolution
                if val2 >= 0:
                    val2 = val2 - resolution
                else:
                    val2 = val2 + resolution
            elif val1 < 0:
                val1 = val1 + resolution
                if val2 >= 0:
                    val2 = val2 - resolution
                else:
                    val2 = val2 + resolution
            else:
                pass
            mse, m = deploy_values(val1, val2, x, y)
            mse_list.append(mse)
            m_list.append(m)
            b_list.append(val2)
    results = pd.DataFrame({'mse': mse_list, 'm': m_list, 'b': b_list})
    global_minimum = results['mse'].min()
    optimal_values = results.loc[results['mse'] == global_minimum]
    slope = optimal_values['m'].iloc[0]
    intercept = optimal_values['b'].iloc[0]
    return global_minimum, slope, intercept, mse_list, b_list, m_list

def deploy_values(m, b, x, y):
    y_pred = (m * x) + b
    mse = ((y - y_pred) ** 2).mean()
    return mse, m

def predict(slope, intercept, x):
    return slope * x + intercept

model_1 = algorithm(test_data['x'], test_data['y'], iteration=500, resolution=0.005)
print(model_1[1], model_1[2])
MSE = model_1[3]
MEAN = model_1[5]
plt.scatter(MEAN, MSE, color='red', label='MSE', s=0.1, alpha=0.2)
plt.xlabel('Mean')
plt.ylabel('MSE')
plt.legend()
plt.show()
# Out:
# 2.0000000000000315 3.7643499428696714e-16

# %%
import pandas as pd
import numpy as np
from random import randint
import matplotlib.pyplot as plt

test_data = pd.DataFrame({
    'x': [1, 2, 3, 4, 5, 6, 7],
    'y': [2, 4, 6, 8, 10, 12, 14]})

def algorithm(x, y, iteration, resolution):
    mse_list, m_list, b_list = [], [], []
    for i in range(iteration):
        val1 = np.random.random() * 10000 - 5000
        val2 = np.random.random() * 10000 - 5000
        for i in range(iteration):
            if val1 > 0:
                val1 = val1 - resolution
                if val2 >= 0:
                    val2 = val2 - resolution
                else:
                    val2 = val2 + resolution
            elif val1 < 0:
                val1 = val1 + resolution
                if val2 >= 0:
                    val2 = val2 - resolution
                else:
                    val2 = val2 + resolution
            else:
                pass
            mse, m = deploy_values(val1, val2, x, y)
            mse_list.append(mse)
            m_list.append(m)
            b_list.append(val2)
    results = pd.DataFrame({'mse': mse_list, 'm': m_list, 'b': b_list})
    global_minimum = results['mse'].min()
    optimal_values = results.loc[results['mse'] == global_minimum]
    slope = optimal_values['m'].iloc[0]
    intercept = optimal_values['b'].iloc[0]
    return global_minimum, slope, intercept, mse_list, b_list, m_list

def deploy_values(m, b, x, y):
    y_pred = (m * x) + b
    mse = ((y - y_pred) ** 2).mean()
    return mse, m

def predict(slope, intercept, x):
    return slope * x + intercept

model_1 = algorithm(test_data['x'], test_data['y'], iteration=1000, resolution=0.001)
print(model_1[1], model_1[2])
MSE = model_1[3]
MEAN = model_1[5]
plt.scatter(MEAN, MSE, color='red', label='MSE', s=0.1, alpha=0.2)
plt.xlabel('Mean')
plt.ylabel('MSE')
plt.legend()
plt.show()
# Out:
# -23.143216484743476 19.06284430708243

# %%
import pandas as pd
import numpy as np
from random import randint
import matplotlib.pyplot as plt

test_data = pd.DataFrame({
    'x': [2, 4, 6, 8, 10, 12, 14],
    'y': [2, 3, 5, 8, 12, 17, 23]})

def algorithm(x, y, iteration, resolution):
    mse_list, m_list, b_list = [], [], []
    for i in range(iteration):
        val1 = np.random.random() * 10000 - 5000
        val2 = np.random.random() * 10000 - 5000
        for i in range(iteration):
            if val1 > 0:
                val1 = val1 - resolution
            elif val1 < 0:
                val1 = val1 + resolution
            else:
                pass
            mse, m = deploy_values(val1, val2, x, y)
            mse_list.append(mse)
            m_list.append(m)
            b_list.append(val2)
    results = pd.DataFrame({'mse': mse_list, 'm': m_list, 'b': b_list})
    global_minimum = results['mse'].min()
    optimal_values = results.loc[results['mse'] == global_minimum]
    slope = optimal_values['m'].iloc[0]
    intercept = optimal_values['b'].iloc[0]
    print(f"Slope: {slope}, Intercept: {intercept}")
    return global_minimum, slope, intercept, mse_list, b_list, m_list

def deploy_values(m, b, x, y):
    y_pred = (m * x) + b
    mse = ((y - y_pred) ** 2).mean()
    return mse, m

def predict(slope, intercept, x):
    return slope * x + intercept

model_1 = algorithm(test_data['x'], test_data['y'], iteration=1000, resolution=0.001)
print(model_1[1], model_1[2])
MSE = model_1[3]
MEAN = model_1[5]
plt.scatter(MEAN, MSE, color='red', label='MSE', s=0.1, alpha=0.2)
plt.xlabel('Mean')
plt.ylabel('MSE')
plt.legend()
plt.show()
# Out:
# Slope: -12.832688808466273, Intercept: -98.49201079782506
# -12.832688808466273 -98.49201079782506

# %%
import pandas as pd
import numpy as np
from random import randint
import matplotlib.pyplot as plt

test_data = pd.DataFrame({
    'x': [2, 4, 6, 8, 10, 12, 14],
    'y': [2, 3, 5, 8, 12, 17, 23]})

def algorithm(x, y, iteration, resolution):
    mse_list, m_list, b_list = [], [], []
    for i in range(iteration):
        val1 = np.random.random() * 10000 - 5000
        val2 = np.random.random() * 10000 - 5000
        for i in range(iteration):
            if val1 > 0:
                val1 = val1 - resolution
            elif val1 < 0:
                val1 = val1 + resolution
            else:
                pass
            mse, m = deploy_values(val1, val2, x, y)
            mse_list.append(mse)
            m_list.append(m)
            b_list.append(val2)
    results = pd.DataFrame({'mse': mse_list, 'm': m_list, 'b': b_list})
    global_minimum = results['mse'].min()
    optimal_values = results.loc[results['mse'] == global_minimum]
    slope = optimal_values['m'].iloc[0]
    intercept = optimal_values['b'].iloc[0]
    print(f"Slope: {slope}, Intercept: {intercept}")
    return global_minimum, slope, intercept, mse_list, b_list, m_list

def deploy_values(m, b, x, y):
    y_pred = (m * x) + b
    mse = ((y - y_pred) ** 2).mean()
    return mse, m

def predict(slope, intercept, x):
    return slope * x + intercept

model_1 = algorithm(test_data['x'], test_data['y'], iteration=1000, resolution=0.001)
print(model_1[1], model_1[2])
MSE = model_1[3]
MEAN = model_1[5]
plt.scatter(MEAN, MSE, color='red', label='MSE', s=0.1, alpha=0.2)
plt.xlabel('Mean')
plt.ylabel('MSE')
plt.legend()
plt.show()
# Out:
# Slope: 20.830311887225122, Intercept: 75.35515569871404
# 20.830311887225122 75.35515569871404
